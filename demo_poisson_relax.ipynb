# %%
# Import packages
import os
import numpy as np
import matplotlib.pyplot as plt
from firedrake import *
from tqdm.auto import tqdm
from numpy.random import default_rng
import matplotlib.pyplot as plt
from firedrake.meshadapt import *
import time

# %%
from firedrake import Constant, cos, sin, Function, SpatialCoordinate, sqrt
from firedrake import assemble, FacetNormal, avg, jump,pi
from firedrake.cython.dmcommon import create_section
import movement.solver_parameters as solver_parameters
from firedrake.petsc import PETSc
from pyadjoint import no_annotations
import ufl
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define mesh and function space
mesh = UnitSquareMesh(128, 128)
P1 = FunctionSpace(mesh, 'CG', 1)
P1_vec = VectorFunctionSpace(mesh, 'CG', 1)

x, y = SpatialCoordinate(mesh)

u = TrialFunction(P1)
v = TestFunction(P1)

a = inner(grad(u), grad(v)) * dx

x = SpatialCoordinate(mesh)
F = Function(P1)
F.interpolate(sin(x[0]*pi)*sin(2*x[1]*pi))
L = F*v*dx

bcs = [DirichletBC(P1, Constant(2.0), (1,))]

uu = Function(P1)
uu.assign(0)
solve(a == L, uu, bcs=bcs, solver_parameters={"mat_type": "matfree",
                                              "ksp_type": "cg",
                                              "ksp_monitor": None,
                                              "pc_type": "python",
                                                "pc_python_type": "firedrake.AssembledPC",
                                                "assembled_pc_type": "ilu"})


fig, axes = plt.subplots()
u_numerical_plt = tricontourf(uu, axes=axes, cmap='coolwarm')
fig.colorbar(u_numerical_plt ,ax = axes)
plt.title("numerical soln 4 possion")
plt.show()
# Out:
#     Residual norms for firedrake_255_ solve.
#     0 KSP Residual norm 2.180790185361e+01
#     1 KSP Residual norm 7.684600965018e+00
#     2 KSP Residual norm 4.343550121007e+00
#     3 KSP Residual norm 3.015354566945e+00
#     4 KSP Residual norm 2.332171217000e+00
#     5 KSP Residual norm 1.907167916305e+00
#     6 KSP Residual norm 1.600879638087e+00
#     7 KSP Residual norm 1.378262622376e+00
#     8 KSP Residual norm 1.217855700069e+00
#     9 KSP Residual norm 1.090096238987e+00
#    10 KSP Residual norm 9.825783842878e-01
#    11 KSP Residual norm 8.961985613689e-01
#    12 KSP Residual norm 8.260039465686e-01
#    13 KSP Residual norm 7.644596577453e-01
#    14 KSP Residual norm 7.111627272960e-01
#    15 KSP Residual norm 6.662200835902e-01
#    16 KSP Residual norm 6.256172980358e-01
#    17 KSP Residual norm 5.882597988913e-01
#    18 KSP Residual norm 5.559012959443e-01
#    19 KSP Residual norm 5.273709333833e-01
#    20 KSP Residual norm 5.009127762442e-01
#    21 KSP Residual norm 4.772144560702e-01
#    22 KSP Residual norm 4.562806885967e-01
#    23 KSP Residual norm 4.366352083980e-01
#    24 KSP Residual norm 4.183333337950e-01
#    25 KSP Residual norm 4.021412321890e-01
#    26 KSP Residual norm 3.871381638450e-01
#    27 KSP Residual norm 3.726180967813e-01
#    28 KSP Residual norm 3.593460679661e-01
#    29 KSP Residual norm 3.479364429967e-01
#    30 KSP Residual norm 3.409520355196e-01
#    31 KSP Residual norm 3.503592919922e-01
#    32 KSP Residual norm 4.061055426246e-01
#    33 KSP Residual norm 5.667760278057e-01
#    34 KSP Residual norm 9.069055283453e-01
#    35 KSP Residual norm 1.111017747671e+00
#    36 KSP Residual norm 5.761697535193e-01
#    37 KSP Residual norm 1.795169088339e-01
#    38 KSP Residual norm 7.378711886297e-02
#    39 KSP Residual norm 5.269278456929e-02
#    40 KSP Residual norm 3.832632239242e-02
#    41 KSP Residual norm 2.974510901404e-02
#    42 KSP Residual norm 2.535160544282e-02
#    43 KSP Residual norm 2.278710885708e-02
#    44 KSP Residual norm 2.189060626985e-02
#    45 KSP Residual norm 2.219781831630e-02
#    46 KSP Residual norm 2.243427771332e-02
#    47 KSP Residual norm 2.347136493816e-02
#    48 KSP Residual norm 2.324411120181e-02
#    49 KSP Residual norm 2.348507228475e-02
#    50 KSP Residual norm 2.251174925314e-02
#    51 KSP Residual norm 2.138106148039e-02
#    52 KSP Residual norm 1.979372118204e-02
#    53 KSP Residual norm 1.758635675085e-02
#    54 KSP Residual norm 1.591284079950e-02
#    55 KSP Residual norm 1.360962030824e-02
#    56 KSP Residual norm 1.143523599814e-02
#    57 KSP Residual norm 9.806897082036e-03
#    58 KSP Residual norm 7.974376882578e-03
#    59 KSP Residual norm 6.567213205706e-03
#    60 KSP Residual norm 5.533420381118e-03
#    61 KSP Residual norm 4.543564060612e-03
#    62 KSP Residual norm 3.827625761605e-03
#    63 KSP Residual norm 3.329891950079e-03
#    64 KSP Residual norm 2.846053604012e-03
#    65 KSP Residual norm 2.410155466490e-03
#    66 KSP Residual norm 2.065635372532e-03
#    67 KSP Residual norm 1.760863292852e-03
#    68 KSP Residual norm 1.563729678028e-03
#    69 KSP Residual norm 1.558840364305e-03
#    70 KSP Residual norm 1.634901203050e-03
#    71 KSP Residual norm 1.432101891267e-03
#    72 KSP Residual norm 1.018685700198e-03
#    73 KSP Residual norm 7.974510474789e-04
#    74 KSP Residual norm 7.448108819152e-04
#    75 KSP Residual norm 6.149731782119e-04
#    76 KSP Residual norm 4.346162328430e-04
#    77 KSP Residual norm 3.844379060218e-04
#    78 KSP Residual norm 3.379240640839e-04
#    79 KSP Residual norm 2.366536375848e-04
#    80 KSP Residual norm 1.969193041557e-04
#    81 KSP Residual norm 1.568265725479e-04
#    82 KSP Residual norm 1.101546850382e-04
#    83 KSP Residual norm 8.949206953938e-05
#    84 KSP Residual norm 7.014401284359e-05
#    85 KSP Residual norm 5.380894592663e-05
#    86 KSP Residual norm 4.037220057448e-05
#    87 KSP Residual norm 3.230367661663e-05
#    88 KSP Residual norm 2.456828471192e-05
#    89 KSP Residual norm 1.895240090205e-05
#    90 KSP Residual norm 1.518427548631e-05
#    91 KSP Residual norm 1.232671469252e-05
#    92 KSP Residual norm 1.032179192504e-05
#    93 KSP Residual norm 9.031873087184e-06
#    94 KSP Residual norm 8.522127138583e-06
#    95 KSP Residual norm 7.930434061134e-06
#    96 KSP Residual norm 7.412374301089e-06
#    97 KSP Residual norm 6.608560317950e-06
#    98 KSP Residual norm 5.535712176778e-06
#    99 KSP Residual norm 4.215297283624e-06
#   100 KSP Residual norm 3.102634723155e-06
#   101 KSP Residual norm 2.224428441130e-06
#   102 KSP Residual norm 1.727370053309e-06

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
u_num_plt = trisurf(uu, axes=ax, cmap='coolwarm')
fig.colorbar(u_num_plt,ax = ax)
plt.title("u_numerical 3D plt")
plt.show()

# %%
#doing modification for monge_ampere move:
class PrimeMover(object):
    """
    Base class for all mesh movers.
    """
    def __init__(self, mesh, monitor_function=None, **kwargs):
        self.mesh = mesh
        self.monitor_function = monitor_function
        self.dim = mesh.topological_dimension()
        if self.dim != 2:
            raise NotImplementedError(f"Dimension {self.dim} has not been considered yet")
        self.gdim = mesh.geometric_dimension()
        self.plex = self.mesh.topology_dm
        self.vertex_indices = self.plex.getDepthStratum(0)
        self.edge_indices = self.plex.getDepthStratum(1)

        # Measures
        degree = kwargs.get('quadrature_degree')
        self.dx = dx(domain=mesh, degree=degree)
        self.ds = ds(domain=mesh, degree=degree)
        self.dS = dS(domain=mesh, degree=degree)

        # Mesh coordinate functions
        self.coord_space = mesh.coordinates.function_space()
        # Mesh coordinate functions comment:下面的 self.xi 是不会发生变化的，所以叫 Computational coordinates
        self._x = Function(mesh.coordinates, name="Physical coordinates")
        self.xi = Function(mesh.coordinates, name="Computational coordinates")
        self.v = Function(self.coord_space, name="Mesh velocity")

    def _get_coordinate_section(self):
        entity_dofs = np.zeros(self.dim+1, dtype=np.int32)
        entity_dofs[0] = self.gdim
        self._coordinate_section = create_section(self.mesh, entity_dofs)
        dm_coords = self.plex.getCoordinateDM()
        dm_coords.setDefaultSection(self._coordinate_section)
        self._coords_local_vec = dm_coords.createLocalVec()
        self._update_plex_coordinates()

    def _update_plex_coordinates(self):
        if not hasattr(self, '_coords_local_vec'):
            self._get_coordinate_section()
        self._coords_local_vec.array[:] = np.reshape(
            self.mesh.coordinates.dat.data_with_halos,
            self._coords_local_vec.array.shape,
        )
        self.plex.setCoordinatesLocal(self._coords_local_vec)

    def _get_edge_vector_section(self):
        entity_dofs = np.zeros(self.dim+1, dtype=np.int32)
        entity_dofs[1] = 1
        self._edge_vector_section = create_section(self.mesh, entity_dofs)

    def coordinate_offset(self, index):
        """
        Get the DMPlex coordinate section offset
        for a given `index`.
        """
        if not hasattr(self, '_coordinate_section'):
            self._get_coordinate_section()
        return self._coordinate_section.getOffset(index)//self.dim

    def edge_vector_offset(self, index):
        """
        Get the DMPlex edge vector section offset
        for a given `index`.
        """
        if not hasattr(self, '_edge_vector_section'):
            self._get_edge_vector_section()
        return self._edge_vector_section.getOffset(index)

    def coordinate(self, index):
        """
        Get the mesh coordinate associated with
        a given `index`.
        """
        return self.mesh.coordinates.dat.data_with_halos[self.get_offset(index)]

    def move(self):
        """
        Move the mesh according to the method of choice.
        """
        raise NotImplementedError("Implement `move` in the derived class.")

    def adapt(self):
        """
        Alias of `move`.
        """
        from warnings import warn
        warn("`adapt` is deprecated (use `move` instead)", DeprecationWarning, stacklevel=2)
        return self.move()

# %%
class MongeAmpereMover_Base(PrimeMover):
    """
    Base class for mesh movers based on the solution
    of Monge-Ampere type equations.
    """
    residual_l2_form = 0
    norm_l2_form = 0
    phi_old = None

    def __init__(self, mesh, monitor_function, u, **kwargs):
        """
        :arg mesh: the physical mesh
        :arg monitor_function: a Python function which takes a mesh as input
        :kwarg phi_init: initial guess for the scalar potential
        :kwarg sigma_init: initial guess for the Hessian
        :kwarg maxiter: maximum number of iterations for the relaxation
        :kwarg rtol: relative tolerance for the residual
        :kwarg dtol: divergence tolerance for the residual
        :kwarg fix_boundary_nodes: should all boundary nodes remain fixed?
        """
        if monitor_function is None:
            raise ValueError("Please supply a monitor function")

        #add u
        self.u = u
        
        # Collect parameters before calling super
        self.pseudo_dt = Constant(kwargs.pop('pseudo_timestep', 0.1))
        self.maxiter = kwargs.pop('maxiter', 1000)
        self.rtol = kwargs.pop('rtol', 1e-3)
        self.dtol = kwargs.pop('dtol', 2.0)
        self.fix_boundary_nodes = kwargs.pop('fix_boundary_nodes', False)
        super().__init__(mesh, monitor_function = monitor_function)

        # Create function spaces
        self.P0 = FunctionSpace(mesh, "DG", 0)
        self.P1 = FunctionSpace(mesh, "CG", 1)
        self.P1_vec = VectorFunctionSpace(mesh, "CG", 1)
        self.P1_ten = TensorFunctionSpace(mesh, "CG", 1)

        # Create objects used during the mesh movement
        self.theta = Constant(0.0)
        self.monitor = Function(self.P1, name="Monitor function")
        self.monitor.interpolate(self.monitor_function(self.mesh, self.u))
        self.volume = Function(self.P0, name="Mesh volume")
        self.volume.interpolate(ufl.CellVolume(mesh))
        self.original_volume = Function(self.volume)
        self.total_volume = assemble(Constant(1.0)*self.dx)
        self.L_P0 = TestFunction(self.P0)*self.monitor*self.dx
        self._grad_phi = Function(self.P1_vec)
        self.grad_phi = Function(self.mesh.coordinates)

    @PETSc.Log.EventDecorator("MongeAmpereBase.apply_initial_guess")
    def apply_initial_guess(self, phi_init=None, sigma_init=None, **kwargs):
        """
        Initialise the approximations to the scalar potential
        and its hessian with an initial guess.

        By default, both are initialised to zero, which corresponds
        to the case where the computational and physical meshes
        coincide.

        :kwarg phi_init: initial guess for the scalar potential
        :kwarg sigma_init: initial guess for the Hessian
        """

        if phi_init is not None and sigma_init is not None:
            self.phi.assign(phi_init)
            self.sigma.assign(sigma_init)
            self.phi_old.assign(phi_init)
            self.sigma_old.assign(sigma_init)
        elif phi_init is not None or sigma_init is not None:
            raise ValueError("Need to initialise both phi *and* sigma")

        
    @property
    @PETSc.Log.EventDecorator("MongeAmpereBase.diagnostics")
    def diagnostics(self):
        """
        Compute diagnostics:
          1) the ratio of the smallest and largest element volumes;
          2) equidistribution of elemental volumes;
          3) relative L2 norm residual.
        """
        v = self.volume.vector().gather()
        minmax = v.min()/v.max()
        mean = v.sum()/v.max()
        w = v.copy() - mean
        w *= w
        std = np.sqrt(w.sum()/w.size)
        equi = std/mean
        residual_l2 = assemble(self.residual_l2_form).dat.norm
        norm_l2 = assemble(self.norm_l2_form).dat.norm
        residual_l2_rel = residual_l2/norm_l2
        return minmax, residual_l2_rel, equi

    @property
    @PETSc.Log.EventDecorator("MongeAmpereBase.update_coordinates")
    def x(self):
        """
        Update the coordinate :class:`Function` using
        the recovered gradient.
        """
        try:
            self.grad_phi.assign(self._grad_phi)
        except Exception:
            self.grad_phi.interpolate(self._grad_phi)
        self._x.assign(self.xi + self.grad_phi)  # x = ξ + grad(φ)
        return self._x
    
    @property
    @PETSc.Log.EventDecorator("MongeAmpereBase.create_l2_projector")
    def l2_projector(self):
        if hasattr(self, '_l2_projector'):
            return self._l2_projector
        u_cts = TrialFunction(self.P1_vec)
        v_cts = TestFunction(self.P1_vec)

        # Domain interior
        phi_grad_v_dx = ufl.inner(v_cts, ufl.grad(self.phi_old))*self.dx
        a = ufl.inner(v_cts, u_cts)*self.dx
        L = phi_grad_v_dx

        # Enforce no movement normal to boundary
        n = ufl.FacetNormal(self.mesh)
        bcs = []
        for i in self.mesh.exterior_facets.unique_markers:
            if self.fix_boundary_nodes:
                bcs.append(DirichletBC(self.P1_vec, 0, i))
                continue

            # Check for axis-aligned boundaries
            _n = [assemble(abs(n[j])*self.ds(i)) for j in range(self.dim)]
            if np.allclose(_n, 0.0):
                raise ValueError(f"Invalid normal vector {_n}")
            else:
                if np.isclose(_n[0], 0.0):
                    bcs.append(DirichletBC(self.P1_vec.sub(1), 0, i))
                    continue
                elif np.isclose(_n[1], 0.0):
                    bcs.append(DirichletBC(self.P1_vec.sub(0), 0, i))
                    continue

            a_bc = ufl.dot(v_cts, n)*ufl.dot(u_cts, n)*self.ds
            bcs.append(EquationBC(a_bc == 0, self._grad_phi, i))

            s = ufl.perp(n)
            a_bc = ufl.dot(v_cts, s)*ufl.dot(u_cts, s)*self.ds
            L_bc = ufl.dot(v_cts, s)*phi_grad_v_dx
            bcs.append(EquationBC(a_bc == L_bc, self._grad_phi, i))

        # Create solver
        problem = LinearVariationalProblem(a, L, self._grad_phi, bcs=bcs)
        sp = {
            "ksp_type": "cg",
            "pc_type": "bjacobi",
            "sub_pc_type": "ilu",
        }
        self._l2_projector = LinearVariationalSolver(problem, solver_parameters=sp)
        return self._l2_projector

# %%
class MongeAmpereMover_Relaxation(MongeAmpereMover_Base):
    r"""
    The elliptic Monge-Ampere equation is solved in a parabolised
    form using a pseudo-time relaxation,

..  math::
        -\frac\partial{\partial\tau}\Delta\phi = m(x)\det(I + H(\phi)) - \theta,

    where :math:`\tau` is the pseudo-time variable. Forward Euler is
    used for the pseudo-time integration (see McRae et al. 2018 for
    details).
    """
    @PETSc.Log.EventDecorator("MongeAmpereMover.__init__")
    def __init__(self, mesh, monitor_function, u, **kwargs):
        """
        :arg mesh: the physical mesh
        :arg monitor_function: a Python function which takes a mesh as input
        :kwarg phi_init: initial guess for the scalar potential
        :kwarg sigma_init: initial guess for the Hessian
        :kwarg pseudo_timestep: pseudo-timestep to use for the relaxation
        :kwarg maxiter: maximum number of iterations for the relaxation
        :kwarg rtol: relative tolerance for the residual
        :kwarg dtol: divergence tolerance for the residual
        """
        def compute_mesh_spacing():
            # Compute the mesh spacing based on the mesh size
            h = sqrt(1.0 / self.mesh.num_cells())
            return h

        
        super().__init__(mesh, monitor_function = monitor_function, u=u, **kwargs)
        h = compute_mesh_spacing()
        self.pseudo_dt = Constant(kwargs.pop('pseudo_timestep',  0.04))
        # Create functions to hold solution data
        self.phi = Function(self.P1)
        self.sigma = Function(self.P1_ten)
        self.phi_old = Function(self.P1)
        self.sigma_old = Function(self.P1_ten)

        #add u to store the 
        self.u = u
        
        # Initialise phi and sigma
        self.apply_initial_guess(**kwargs)

        # Setup residuals
        I = ufl.Identity(self.dim)
        self.theta_form = self.monitor*ufl.det(I + self.sigma_old)*self.dx
        self.residual = self.monitor*ufl.det(I + self.sigma_old) - self.theta
        psi = TestFunction(self.P1)
        self.residual_l2_form = psi*self.residual*self.dx
        self.norm_l2_form = psi*self.theta*self.dx

    @property
    @PETSc.Log.EventDecorator("MongeAmpereMover.create_pseudotimestepper")
    def pseudotimestepper(self):
        """
        Setup the pseudo-timestepper for the relaxation method.
        """
        if hasattr(self, '_pseudotimestepper'):
            return self._pseudotimestepper
        phi = TrialFunction(self.P1)
        psi = TestFunction(self.P1)
        a = ufl.inner(ufl.grad(psi), ufl.grad(phi))*self.dx
        L = ufl.inner(ufl.grad(psi), ufl.grad(self.phi_old))*self.dx \
            + self.pseudo_dt*psi*self.residual*self.dx
        problem = LinearVariationalProblem(a, L, self.phi)
        sp = {
            "ksp_type": "cg",
            "pc_type": "gamg",
        }
        nullspace = VectorSpaceBasis(constant=True)
        self._pseudotimestepper = LinearVariationalSolver(
            problem, solver_parameters=sp,
            nullspace=nullspace, transpose_nullspace=nullspace,
        )
        return self._pseudotimestepper

    @property
    @PETSc.Log.EventDecorator("MongeAmpereMover.create_equidistributor")
    def equidistributor(self):
        """
        Setup the equidistributor for the relaxation method.
        """
        if hasattr(self, '_equidistributor'):
            return self._equidistributor
        if self.dim != 2:
            raise NotImplementedError  # TODO
        n = ufl.FacetNormal(self.mesh)
        sigma = TrialFunction(self.P1_ten)
        tau = TestFunction(self.P1_ten)
        a = ufl.inner(tau, sigma)*self.dx
        L = -ufl.dot(ufl.div(tau), ufl.grad(self.phi))*self.dx \
            + (tau[0, 1]*n[1]*self.phi.dx(0) + tau[1, 0]*n[0]*self.phi.dx(1))*self.ds
        problem = LinearVariationalProblem(a, L, self.sigma)
        sp = {
            "ksp_type": "cg",
            "pc_type": "bjacobi",
            "sub_pc_type": "ilu",
        }
        self._equidistributor = LinearVariationalSolver(problem, solver_parameters=sp)
        return self._equidistributor

    @PETSc.Log.EventDecorator("MongeAmpereMover.move")
    def move(self):
        """
        Run the relaxation method to convergence and update the mesh.
        """
        for i in range(self.maxiter):

            # lz project
            self.l2_projector.solve()

            # Update mesh coordinates
            self.mesh.coordinates.assign(self.x)

            # Update monitor function
            self.monitor.interpolate(self.monitor_function(self.mesh,self.u))
            assemble(self.L_P0, tensor=self.volume)
            self.volume.interpolate(self.volume / self.original_volume)
            self.mesh.coordinates.assign(self.xi)

            # Evaluate normalisation coefficient
            self.theta.assign(assemble(self.theta_form) / self.total_volume)

            # Check convergence criteria
            minmax, residual, equi = self.diagnostics
            if i == 0:
                initial_norm = residual
            PETSc.Sys.Print(f"{i:4d}"
            f"   Min/Max {minmax:10.4e}"
            f"   Residual {residual:10.4e}"
            f"   Equidistribution {equi:10.4e}")
            if residual < self.rtol:

                PETSc.Sys.Print(f"Converged in {i+1} iterations.")
                break
            if residual > self.dtol*initial_norm:
                raise ConvergenceError(f"Diverged after {i+1} iterations.")
            if i == self.maxiter-1:
                raise ConvergenceError(f"Failed to converge in {i+1} iterations.")

            # Apply pseudotimestepper and equidistributor
            self.pseudotimestepper.solve()
            self.equidistributor.solve()
            self.phi_old.assign(self.phi)
            self.sigma_old.assign(self.sigma)
        self.mesh.coordinates.assign(self.x)
        return i

# %%
class MongeAmpereMover_QuasiNewton(MongeAmpereMover_Base):
    r"""
    The elliptic Monge-Ampere equation is solved using a quasi-Newton
    method (see McRae et al. 2018 for details).
    """
    @PETSc.Log.EventDecorator("MongeAmpereMover.__init__")
    def __init__(self, mesh, monitor_function, u, **kwargs):
        """
        :arg mesh: the physical mesh
        :arg monitor_function: a Python function which takes a mesh as input
        :kwarg maxiter: maximum number of iterations for the relaxation
        :kwarg rtol: relative tolerance for the residual
        :kwarg dtol: divergence tolerance for the residual
        """
        super().__init__(mesh, monitor_function=monitor_function, u=u, **kwargs)

        # Create functions to hold solution data
        self.u = u
        self.V = self.P1*self.P1_ten
        self.phisigma = Function(self.V)
        self.phi, self.sigma = self.phisigma.split()
        self.phisigma_old = Function(self.V)
        self.phi_old, self.sigma_old = self.phisigma_old.split()

        # Initialise phi and sigma
        self.apply_initial_guess(**kwargs)

        # Setup residuals
        I = ufl.Identity(self.dim)
        self.theta_form = self.monitor*ufl.det(I + self.sigma_old)*self.dx
        self.residual = self.monitor*ufl.det(I + self.sigma_old) - self.theta
        psi = TestFunction(self.P1)
        self.residual_l2_form = psi*self.residual*self.dx
        self.norm_l2_form = psi*self.theta*self.dx

    @property
    @PETSc.Log.EventDecorator("MongeAmpereMover.create_equidistributor")
    def equidistributor(self):
        """
        Setup the equidistributor for the quasi-newton method.
        """
        if hasattr(self, '_equidistributor'):
            return self._equidistributor
        if self.dim != 2:
            raise NotImplementedError  # TODO
        n = ufl.FacetNormal(self.mesh)
        I = ufl.Identity(self.dim)
        phi, sigma = split(self.phisigma)
        psi, tau = TestFunctions(self.V)
        F = ufl.inner(tau, sigma)*self.dx \
            + ufl.dot(ufl.div(tau), ufl.grad(phi))*self.dx \
            - (tau[0, 1]*n[1]*phi.dx(0) + tau[1, 0]*n[0]*phi.dx(1))*self.ds \
            - psi*(self.monitor*ufl.det(I + sigma) - self.theta)*self.dx
        phi, sigma = TrialFunctions(self.V)

        @PETSc.Log.EventDecorator("MongeAmpereMover.update_monitor")
        def update_monitor(cursol):
            """
            Callback for updating the monitor function.
            """
            with self.phisigma_old.dat.vec as v:
                cursol.copy(v)
            self.l2_projector.solve()
            self.mesh.coordinates.assign(self.x)
            self.monitor.interpolate(self.monitor_function(self.mesh, self.u))
            self.mesh.coordinates.assign(self.xi)
            self.theta.assign(assemble(self.theta_form)*self.total_volume**(-1))

        # Custom preconditioner
        Jp = ufl.inner(tau, sigma)*self.dx \
            + phi*psi*self.dx \
            + ufl.inner(ufl.grad(phi), ufl.grad(psi))*self.dx

        # Setup the variational problem
        problem = NonlinearVariationalProblem(F, self.phisigma, Jp=Jp)
        nullspace = MixedVectorSpaceBasis(self.V, [VectorSpaceBasis(constant=True), self.V.sub(1)])
        sp = solver_parameters.serial_qn if COMM_WORLD.size == 1 else solver_parameters.parallel_qn
        sp['snes_atol'] = self.rtol
        sp['snes_max_it'] = self.maxiter
        self._equidistributor = NonlinearVariationalSolver(problem,
                                                                     nullspace=nullspace,
                                                                     transpose_nullspace=nullspace,
                                                                     pre_function_callback=update_monitor,
                                                                     pre_jacobian_callback=update_monitor,
                                                                     solver_parameters=sp)

        @no_annotations
        @PETSc.Log.EventDecorator("MongeAmpereMover.monitor")
        def monitor(snes, i, rnorm):
            """
            Print progress of the optimisation to screen.

            Note that convergence is not actually checked.
            """
            cursol = snes.getSolution()
            update_monitor(cursol)
            self.mesh.coordinates.assign(self.x)
            assemble(self.L_P0, tensor=self.volume)
            self.volume.interpolate(self.volume/self.original_volume)
            self.mesh.coordinates.assign(self.xi)
            minmax, residual, equi = self.diagnostics
            PETSc.Sys.Print(f"{i:4d}"
                            f"   Min/Max {minmax:10.4e}"
                            f"   Residual {residual:10.4e}"
                            f"   Equidistribution {equi:10.4e}")

        self.snes = self._equidistributor.snes
        self.snes.setMonitor(monitor)
        return self._equidistributor

    @PETSc.Log.EventDecorator("MongeAmpereMover.move")
    def move(self):
        """
        Run the quasi-Newton method to convergence and update the mesh.
        """
        try:
            self.equidistributor.solve()
            i = self.snes.getIterationNumber()
            PETSc.Sys.Print(f"Converged in {i} iterations.")
        except ConvergenceError:
            i = self.snes.getIterationNumber()
            raise ConvergenceError(f"Failed to converge in {i} iterations.")
        self.mesh.coordinates.assign(self.x)
        return i


def monge_ampere(mesh, monitor_function, method='relaxation', **kwargs):
    r"""
    Movement of a `mesh` is determined by a `monitor_function`
    :math:`m` and the Monge-Ampère type equation

..  math::
        m(x)\det(I + H(\phi)) = \theta,

    for a scalar potential :math:`\phi`, where :math:`I` is the
    identity matrix, :math:`\theta` is a normalisation coefficient
    and :math:`H(\phi)` denotes the Hessian of :math:`\phi` with
    respect to the coordinates :math:`\xi` of the computational mesh.

    The physical mesh coordinates :math:`x` are updated according to

..  math::
        x = \xi + \nabla\phi.

    :arg mesh: the physical mesh
    :arg monitor_function: a Python function which takes a mesh as input
    :kwarg method: choose from 'relaxation' and 'quasi_newton'
    :kwarg phi_init: initial guess for the scalar potential
    :kwarg sigma_init: initial guess for the Hessian
    :return: converged scalar potential and Hessian
    """
    if method == 'relaxation':
        mover = MongeAmpereMover_Relaxation(mesh, monitor_function, **kwargs)
    elif method == 'quasi_newton':
        mover = MongeAmpereMover_QuasiNewton(mesh, monitor_function, **kwargs)
    else:
        raise ValueError(f"Monge-Ampere solver {method} not recognised.")
    mover.adapt()
    return mover.phi, mover.sigma

# %%
def MongeAmpereMover(mesh, monitor_function, u, method='relaxation', **kwargs):
    r"""
    Movement of a `mesh` is determined by a `monitor_function`
    :math:`m` and the Monge-Ampère type equation

    ..  math::
        m(x)\det(I + H(\phi)) = \theta,

    for a scalar potential :math:`\phi`, where :math:`I` is the
    identity matrix, :math:`\theta` is a normalisation coefficient
    and :math:`H(\phi)` denotes the Hessian of :math:`\phi` with
    respect to the coordinates :math:`\xi` of the computational mesh.

    The physical mesh coordinates :math:`x` are updated according to

    ..  math::
        x = \xi + \nabla\phi.

    :arg mesh: the physical mesh
    :arg monitor_function: a Python function which takes a mesh as input
    :arg u: the numerical sol of u to calculate m(x)
    :kwarg method: choose from 'relaxation' and 'quasi_newton'
    :return: converged scalar potential and Hessian
    """
    if method == 'relaxation':
        return MongeAmpereMover_Relaxation(mesh, monitor_function, u, **kwargs)
    elif method == 'quasi_newton':
        return MongeAmpereMover_QuasiNewton(mesh, monitor_function, u, **kwargs)
    else:
        raise ValueError(f"Method {method} not recognised.")

# %%
function_spaces_r = []
spatial_coordinates_r = []
u_s = []
adapted_meshes = []
elapsed_times = []

for i in (40,60): 
    mesh = RectangleMesh(i,i,1,1)
    V = FunctionSpace(mesh, 'CG', 1)
    x, y = SpatialCoordinate(mesh)

    u = Function(V)
    v = TestFunction(V)

    x,y = SpatialCoordinate(mesh)
    f = Function(V)
    f.interpolate(sin(x*pi)*sin(2*y*pi))


    bcs = DirichletBC(V, Constant(2.0), (1,))

    F = (inner(grad(u), grad(v)) - inner(f, v)) * dx
    solve(F == 0, u, solver_parameters={'ksp_type': 'preonly', 'pc_type': 'lu'}, bcs=bcs)
    u_s.append(u)

    start_time = time.time()
    def pde_monitor(mesh,u):

        # Define the Riemannian metric
        P1_tensor = TensorFunctionSpace(mesh, "CG", 1)
        metric = RiemannianMetric(P1_tensor)

        # Compute the Hessian of the current solution
        #注意，计算hessian矩阵的过程是否可以优化或者加速
        hessian = metric.compute_hessian(u)
        P1 = FunctionSpace(mesh, "CG", 1)
        
        beta = Constant(2)
        
        Hnorm = Function(P1).interpolate(sqrt(inner(hessian, hessian)))
        Hnorm_max = Hnorm.dat.data[:].max()                                 
        monitor = 1 + beta * Hnorm/Hnorm_max
        
        return monitor
    mover = MongeAmpereMover(mesh, pde_monitor, u, method="relaxation")
    mover.move()
    end_time = time.time()
    elapsed_time = end_time - start_time
    elapsed_times.append(elapsed_time)
    print(f"Time taken for movement for {i}x{i} Mesh: {elapsed_time} seconds")
    adapted_meshes.append(mesh)
# Out:
# firedrake:WARNING No comm specified for VectorSpaceBasis, COMM_WORLD assumed
#    0   Min/Max 3.5296e-01   Residual 2.1081e-01   Equidistribution 9.9908e-01
#    1   Min/Max 3.7821e-01   Residual 2.0558e-01   Equidistribution 9.9911e-01
#    2   Min/Max 4.0055e-01   Residual 2.0032e-01   Equidistribution 9.9914e-01
#    3   Min/Max 4.2381e-01   Residual 1.9491e-01   Equidistribution 9.9917e-01
#    4   Min/Max 4.4914e-01   Residual 1.8939e-01   Equidistribution 9.9919e-01
#    5   Min/Max 4.7428e-01   Residual 1.8380e-01   Equidistribution 9.9922e-01
#    6   Min/Max 4.9098e-01   Residual 1.7819e-01   Equidistribution 9.9923e-01
#    7   Min/Max 5.0437e-01   Residual 1.7259e-01   Equidistribution 9.9924e-01
#    8   Min/Max 5.2467e-01   Residual 1.6260e-01   Equidistribution 9.9926e-01
#    9   Min/Max 5.4580e-01   Residual 1.5089e-01   Equidistribution 9.9928e-01
#   10   Min/Max 5.6769e-01   Residual 1.3942e-01   Equidistribution 9.9930e-01
#   11   Min/Max 5.8597e-01   Residual 1.2845e-01   Equidistribution 9.9932e-01
#   12   Min/Max 6.0568e-01   Residual 1.1761e-01   Equidistribution 9.9934e-01
#   13   Min/Max 6.2215e-01   Residual 1.0797e-01   Equidistribution 9.9935e-01
#   14   Min/Max 6.3713e-01   Residual 9.8226e-02   Equidistribution 9.9937e-01
#   15   Min/Max 6.4813e-01   Residual 9.0177e-02   Equidistribution 9.9938e-01
#   16   Min/Max 6.5680e-01   Residual 8.1838e-02   Equidistribution 9.9939e-01
#   17   Min/Max 6.6713e-01   Residual 7.4466e-02   Equidistribution 9.9940e-01
#   18   Min/Max 6.6691e-01   Residual 6.7137e-02   Equidistribution 9.9941e-01
#   19   Min/Max 6.6633e-01   Residual 6.1628e-02   Equidistribution 9.9942e-01
#   20   Min/Max 6.7138e-01   Residual 5.6014e-02   Equidistribution 9.9944e-01
#   21   Min/Max 6.6536e-01   Residual 5.1921e-02   Equidistribution 9.9944e-01
#   22   Min/Max 6.6312e-01   Residual 4.9062e-02   Equidistribution 9.9945e-01
#   23   Min/Max 6.6497e-01   Residual 4.5937e-02   Equidistribution 9.9946e-01
#   24   Min/Max 6.6660e-01   Residual 4.3525e-02   Equidistribution 9.9947e-01
#   25   Min/Max 6.6324e-01   Residual 4.1752e-02   Equidistribution 9.9947e-01
#   26   Min/Max 6.6144e-01   Residual 4.0369e-02   Equidistribution 9.9947e-01
#   27   Min/Max 6.5817e-01   Residual 3.8776e-02   Equidistribution 9.9947e-01
#   28   Min/Max 6.5801e-01   Residual 3.7377e-02   Equidistribution 9.9948e-01
#   29   Min/Max 6.5605e-01   Residual 3.6150e-02   Equidistribution 9.9948e-01
#   30   Min/Max 6.5512e-01   Residual 3.4956e-02   Equidistribution 9.9948e-01
#   31   Min/Max 6.5579e-01   Residual 3.3744e-02   Equidistribution 9.9948e-01
#   32   Min/Max 6.5487e-01   Residual 3.2527e-02   Equidistribution 9.9948e-01
#   33   Min/Max 6.5789e-01   Residual 3.1418e-02   Equidistribution 9.9948e-01
#   34   Min/Max 6.6560e-01   Residual 3.0431e-02   Equidistribution 9.9949e-01
#   35   Min/Max 6.7166e-01   Residual 2.9427e-02   Equidistribution 9.9949e-01
#   36   Min/Max 6.7364e-01   Residual 2.8358e-02   Equidistribution 9.9949e-01
#   37   Min/Max 6.7841e-01   Residual 2.7216e-02   Equidistribution 9.9949e-01
#   38   Min/Max 6.8567e-01   Residual 2.6022e-02   Equidistribution 9.9949e-01
#   39   Min/Max 6.9515e-01   Residual 2.4814e-02   Equidistribution 9.9949e-01
#   40   Min/Max 7.0621e-01   Residual 2.3640e-02   Equidistribution 9.9950e-01
#   41   Min/Max 7.1043e-01   Residual 2.2555e-02   Equidistribution 9.9949e-01
#   42   Min/Max 7.1296e-01   Residual 2.1615e-02   Equidistribution 9.9949e-01
#   43   Min/Max 7.1621e-01   Residual 2.0873e-02   Equidistribution 9.9949e-01
#   44   Min/Max 7.1951e-01   Residual 2.0064e-02   Equidistribution 9.9949e-01
#   45   Min/Max 7.2525e-01   Residual 1.9162e-02   Equidistribution 9.9949e-01
#   46   Min/Max 7.3265e-01   Residual 1.8327e-02   Equidistribution 9.9950e-01
#   47   Min/Max 7.4143e-01   Residual 1.7535e-02   Equidistribution 9.9950e-01
#   48   Min/Max 7.5135e-01   Residual 1.6775e-02   Equidistribution 9.9951e-01
#   49   Min/Max 7.5752e-01   Residual 1.6042e-02   Equidistribution 9.9951e-01
#   50   Min/Max 7.6295e-01   Residual 1.5338e-02   Equidistribution 9.9951e-01
#   51   Min/Max 7.6943e-01   Residual 1.4665e-02   Equidistribution 9.9951e-01
#   52   Min/Max 7.7647e-01   Residual 1.4024e-02   Equidistribution 9.9951e-01
#   53   Min/Max 7.8332e-01   Residual 1.3419e-02   Equidistribution 9.9951e-01
#   54   Min/Max 7.9051e-01   Residual 1.2849e-02   Equidistribution 9.9951e-01
#   55   Min/Max 7.9790e-01   Residual 1.2314e-02   Equidistribution 9.9951e-01
#   56   Min/Max 8.0539e-01   Residual 1.1811e-02   Equidistribution 9.9951e-01
#   57   Min/Max 8.1287e-01   Residual 1.1338e-02   Equidistribution 9.9951e-01
#   58   Min/Max 8.1823e-01   Residual 1.0890e-02   Equidistribution 9.9951e-01
#   59   Min/Max 8.2358e-01   Residual 1.0464e-02   Equidistribution 9.9952e-01
#   60   Min/Max 8.2825e-01   Residual 1.0056e-02   Equidistribution 9.9952e-01
#   61   Min/Max 8.3164e-01   Residual 9.6625e-03   Equidistribution 9.9952e-01
#   62   Min/Max 8.3514e-01   Residual 9.2810e-03   Equidistribution 9.9952e-01
#   63   Min/Max 8.3871e-01   Residual 8.9094e-03   Equidistribution 9.9952e-01
#   64   Min/Max 8.4230e-01   Residual 8.5464e-03   Equidistribution 9.9952e-01
#   65   Min/Max 8.4589e-01   Residual 8.1913e-03   Equidistribution 9.9952e-01
#   66   Min/Max 8.4944e-01   Residual 7.8439e-03   Equidistribution 9.9952e-01
#   67   Min/Max 8.5292e-01   Residual 7.5045e-03   Equidistribution 9.9952e-01
#   68   Min/Max 8.5600e-01   Residual 7.1733e-03   Equidistribution 9.9952e-01
#   69   Min/Max 8.5716e-01   Residual 6.8508e-03   Equidistribution 9.9952e-01
#   70   Min/Max 8.5796e-01   Residual 6.5377e-03   Equidistribution 9.9952e-01
#   71   Min/Max 8.5874e-01   Residual 6.2344e-03   Equidistribution 9.9952e-01
#   72   Min/Max 8.5949e-01   Residual 5.9415e-03   Equidistribution 9.9952e-01
#   73   Min/Max 8.6022e-01   Residual 5.6591e-03   Equidistribution 9.9952e-01
#   74   Min/Max 8.6092e-01   Residual 5.3878e-03   Equidistribution 9.9952e-01
#   75   Min/Max 8.6085e-01   Residual 5.1276e-03   Equidistribution 9.9952e-01
#   76   Min/Max 8.6072e-01   Residual 4.8786e-03   Equidistribution 9.9952e-01
#   77   Min/Max 8.6062e-01   Residual 4.6410e-03   Equidistribution 9.9952e-01
#   78   Min/Max 8.6056e-01   Residual 4.4149e-03   Equidistribution 9.9953e-01
#   79   Min/Max 8.6052e-01   Residual 4.2001e-03   Equidistribution 9.9953e-01
#   80   Min/Max 8.6051e-01   Residual 3.9966e-03   Equidistribution 9.9953e-01
#   81   Min/Max 8.6053e-01   Residual 3.8044e-03   Equidistribution 9.9953e-01
#   82   Min/Max 8.6057e-01   Residual 3.6234e-03   Equidistribution 9.9953e-01
#   83   Min/Max 8.6063e-01   Residual 3.4533e-03   Equidistribution 9.9953e-01
#   84   Min/Max 8.6063e-01   Residual 3.2940e-03   Equidistribution 9.9953e-01
#   85   Min/Max 8.6064e-01   Residual 3.1451e-03   Equidistribution 9.9953e-01
#   86   Min/Max 8.6068e-01   Residual 3.0062e-03   Equidistribution 9.9953e-01
#   87   Min/Max 8.6072e-01   Residual 2.8768e-03   Equidistribution 9.9953e-01
#   88   Min/Max 8.6077e-01   Residual 2.7564e-03   Equidistribution 9.9953e-01
#   89   Min/Max 8.6083e-01   Residual 2.6442e-03   Equidistribution 9.9953e-01
#   90   Min/Max 8.6090e-01   Residual 2.5395e-03   Equidistribution 9.9953e-01
#   91   Min/Max 8.6098e-01   Residual 2.4415e-03   Equidistribution 9.9953e-01
#   92   Min/Max 8.6105e-01   Residual 2.3494e-03   Equidistribution 9.9953e-01
#   93   Min/Max 8.6113e-01   Residual 2.2626e-03   Equidistribution 9.9953e-01
#   94   Min/Max 8.6121e-01   Residual 2.1803e-03   Equidistribution 9.9953e-01
#   95   Min/Max 8.6129e-01   Residual 2.1021e-03   Equidistribution 9.9953e-01
#   96   Min/Max 8.6136e-01   Residual 2.0274e-03   Equidistribution 9.9953e-01
#   97   Min/Max 8.6144e-01   Residual 1.9560e-03   Equidistribution 9.9953e-01
#   98   Min/Max 8.6151e-01   Residual 1.8875e-03   Equidistribution 9.9953e-01
#   99   Min/Max 8.6158e-01   Residual 1.8218e-03   Equidistribution 9.9953e-01
#  100   Min/Max 8.6165e-01   Residual 1.7588e-03   Equidistribution 9.9953e-01
#  101   Min/Max 8.6171e-01   Residual 1.6985e-03   Equidistribution 9.9953e-01
#  102   Min/Max 8.6177e-01   Residual 1.6407e-03   Equidistribution 9.9953e-01
#  103   Min/Max 8.6183e-01   Residual 1.5855e-03   Equidistribution 9.9953e-01
#  104   Min/Max 8.6188e-01   Residual 1.5328e-03   Equidistribution 9.9953e-01
#  105   Min/Max 8.6194e-01   Residual 1.4825e-03   Equidistribution 9.9953e-01
#  106   Min/Max 8.6198e-01   Residual 1.4346e-03   Equidistribution 9.9953e-01
#  107   Min/Max 8.6203e-01   Residual 1.3890e-03   Equidistribution 9.9953e-01
#  108   Min/Max 8.6208e-01   Residual 1.3457e-03   Equidistribution 9.9953e-01
#  109   Min/Max 8.6212e-01   Residual 1.3044e-03   Equidistribution 9.9953e-01
#  110   Min/Max 8.6216e-01   Residual 1.2653e-03   Equidistribution 9.9953e-01
#  111   Min/Max 8.6219e-01   Residual 1.2282e-03   Equidistribution 9.9953e-01
#  112   Min/Max 8.6223e-01   Residual 1.1930e-03   Equidistribution 9.9953e-01
#  113   Min/Max 8.6226e-01   Residual 1.1596e-03   Equidistribution 9.9953e-01
#  114   Min/Max 8.6230e-01   Residual 1.1280e-03   Equidistribution 9.9953e-01
#  115   Min/Max 8.6232e-01   Residual 1.0980e-03   Equidistribution 9.9953e-01
#  116   Min/Max 8.6235e-01   Residual 1.0696e-03   Equidistribution 9.9953e-01
#  117   Min/Max 8.6238e-01   Residual 1.0426e-03   Equidistribution 9.9953e-01
#  118   Min/Max 8.6240e-01   Residual 1.0169e-03   Equidistribution 9.9953e-01
#  119   Min/Max 8.6242e-01   Residual 9.9232e-04   Equidistribution 9.9953e-01
# Converged in 120 iterations.
# Time taken for movement for 40x40 Mesh: 74.99526190757751 seconds
# firedrake:WARNING No comm specified for VectorSpaceBasis, COMM_WORLD assumed
#    0   Min/Max 3.4797e-01   Residual 2.1207e-01   Equidistribution 9.9959e-01
#    1   Min/Max 3.7132e-01   Residual 2.0690e-01   Equidistribution 9.9960e-01
#    2   Min/Max 3.9832e-01   Residual 2.0156e-01   Equidistribution 9.9962e-01
#    3   Min/Max 4.2398e-01   Residual 1.9608e-01   Equidistribution 9.9963e-01
#    4   Min/Max 4.4900e-01   Residual 1.9051e-01   Equidistribution 9.9964e-01
#    5   Min/Max 4.7304e-01   Residual 1.8485e-01   Equidistribution 9.9965e-01
#    6   Min/Max 4.8578e-01   Residual 1.7916e-01   Equidistribution 9.9966e-01
#    7   Min/Max 4.9843e-01   Residual 1.7346e-01   Equidistribution 9.9966e-01
#    8   Min/Max 5.1932e-01   Residual 1.6301e-01   Equidistribution 9.9967e-01
#    9   Min/Max 5.3982e-01   Residual 1.5203e-01   Equidistribution 9.9968e-01
#   10   Min/Max 5.5971e-01   Residual 1.4130e-01   Equidistribution 9.9969e-01
#   11   Min/Max 5.7694e-01   Residual 1.2977e-01   Equidistribution 9.9969e-01
#   12   Min/Max 5.9626e-01   Residual 1.1817e-01   Equidistribution 9.9970e-01
#   13   Min/Max 6.1324e-01   Residual 1.0746e-01   Equidistribution 9.9971e-01
#   14   Min/Max 6.2851e-01   Residual 9.7820e-02   Equidistribution 9.9972e-01
#   15   Min/Max 6.4087e-01   Residual 8.8718e-02   Equidistribution 9.9972e-01
#   16   Min/Max 6.5057e-01   Residual 8.0721e-02   Equidistribution 9.9973e-01
#   17   Min/Max 6.6159e-01   Residual 7.2885e-02   Equidistribution 9.9973e-01
#   18   Min/Max 6.7083e-01   Residual 6.5843e-02   Equidistribution 9.9974e-01
#   19   Min/Max 6.7335e-01   Residual 5.9665e-02   Equidistribution 9.9974e-01
#   20   Min/Max 6.7059e-01   Residual 5.5216e-02   Equidistribution 9.9975e-01
#   21   Min/Max 6.6179e-01   Residual 5.1235e-02   Equidistribution 9.9975e-01
#   22   Min/Max 6.5215e-01   Residual 4.8574e-02   Equidistribution 9.9975e-01
#   23   Min/Max 6.4663e-01   Residual 4.6039e-02   Equidistribution 9.9976e-01
#   24   Min/Max 6.3903e-01   Residual 4.4469e-02   Equidistribution 9.9976e-01
#   25   Min/Max 6.3106e-01   Residual 4.2798e-02   Equidistribution 9.9976e-01
#   26   Min/Max 6.2367e-01   Residual 4.1519e-02   Equidistribution 9.9976e-01
#   27   Min/Max 6.1775e-01   Residual 4.0393e-02   Equidistribution 9.9976e-01
#   28   Min/Max 6.1314e-01   Residual 3.9319e-02   Equidistribution 9.9976e-01
#   29   Min/Max 6.1578e-01   Residual 3.8299e-02   Equidistribution 9.9976e-01
#   30   Min/Max 6.1276e-01   Residual 3.7389e-02   Equidistribution 9.9977e-01
#   31   Min/Max 6.1551e-01   Residual 3.6296e-02   Equidistribution 9.9977e-01
#   32   Min/Max 6.1217e-01   Residual 3.5081e-02   Equidistribution 9.9977e-01
#   33   Min/Max 6.1147e-01   Residual 3.4275e-02   Equidistribution 9.9977e-01
#   34   Min/Max 6.0942e-01   Residual 3.3191e-02   Equidistribution 9.9977e-01
#   35   Min/Max 6.1002e-01   Residual 3.1835e-02   Equidistribution 9.9977e-01
#   36   Min/Max 6.1085e-01   Residual 3.0411e-02   Equidistribution 9.9977e-01
#   37   Min/Max 6.1206e-01   Residual 2.9609e-02   Equidistribution 9.9977e-01
#   38   Min/Max 6.1906e-01   Residual 2.8606e-02   Equidistribution 9.9977e-01
#   39   Min/Max 6.2581e-01   Residual 2.7419e-02   Equidistribution 9.9977e-01
#   40   Min/Max 6.2751e-01   Residual 2.6149e-02   Equidistribution 9.9977e-01
#   41   Min/Max 6.3357e-01   Residual 2.4961e-02   Equidistribution 9.9977e-01
#   42   Min/Max 6.4507e-01   Residual 2.4027e-02   Equidistribution 9.9977e-01
#   43   Min/Max 6.5541e-01   Residual 2.3188e-02   Equidistribution 9.9977e-01
#   44   Min/Max 6.6033e-01   Residual 2.2342e-02   Equidistribution 9.9977e-01
#   45   Min/Max 6.6530e-01   Residual 2.1495e-02   Equidistribution 9.9977e-01
#   46   Min/Max 6.7311e-01   Residual 2.0693e-02   Equidistribution 9.9977e-01
#   47   Min/Max 6.7894e-01   Residual 2.0003e-02   Equidistribution 9.9977e-01
#   48   Min/Max 6.8765e-01   Residual 1.9495e-02   Equidistribution 9.9977e-01
#   49   Min/Max 6.9746e-01   Residual 1.9232e-02   Equidistribution 9.9977e-01
#   50   Min/Max 7.0478e-01   Residual 1.9250e-02   Equidistribution 9.9977e-01
#   51   Min/Max 7.1056e-01   Residual 1.8915e-02   Equidistribution 9.9977e-01
#   52   Min/Max 7.1916e-01   Residual 1.8136e-02   Equidistribution 9.9977e-01
#   53   Min/Max 7.2999e-01   Residual 1.7435e-02   Equidistribution 9.9977e-01
#   54   Min/Max 7.4261e-01   Residual 1.6794e-02   Equidistribution 9.9978e-01
#   55   Min/Max 7.5202e-01   Residual 1.6199e-02   Equidistribution 9.9978e-01
#   56   Min/Max 7.5906e-01   Residual 1.5634e-02   Equidistribution 9.9978e-01
#   57   Min/Max 7.6744e-01   Residual 1.5087e-02   Equidistribution 9.9978e-01
#   58   Min/Max 7.7688e-01   Residual 1.4552e-02   Equidistribution 9.9978e-01
#   59   Min/Max 7.8367e-01   Residual 1.4027e-02   Equidistribution 9.9978e-01
#   60   Min/Max 7.9120e-01   Residual 1.3518e-02   Equidistribution 9.9978e-01
#   61   Min/Max 7.9793e-01   Residual 1.3023e-02   Equidistribution 9.9978e-01
#   62   Min/Max 8.0393e-01   Residual 1.2543e-02   Equidistribution 9.9978e-01
#   63   Min/Max 8.0963e-01   Residual 1.2077e-02   Equidistribution 9.9978e-01
#   64   Min/Max 8.1438e-01   Residual 1.1622e-02   Equidistribution 9.9978e-01
#   65   Min/Max 8.1941e-01   Residual 1.1169e-02   Equidistribution 9.9978e-01
#   66   Min/Max 8.2462e-01   Residual 1.0733e-02   Equidistribution 9.9979e-01
#   67   Min/Max 8.2995e-01   Residual 1.0321e-02   Equidistribution 9.9979e-01
#   68   Min/Max 8.3486e-01   Residual 9.9322e-03   Equidistribution 9.9979e-01
#   69   Min/Max 8.3691e-01   Residual 9.5659e-03   Equidistribution 9.9979e-01
#   70   Min/Max 8.4145e-01   Residual 9.2192e-03   Equidistribution 9.9979e-01
#   71   Min/Max 8.4673e-01   Residual 8.8910e-03   Equidistribution 9.9979e-01
#   72   Min/Max 8.4380e-01   Residual 8.5781e-03   Equidistribution 9.9979e-01
#   73   Min/Max 8.4366e-01   Residual 8.2802e-03   Equidistribution 9.9979e-01
#   74   Min/Max 8.4140e-01   Residual 8.0048e-03   Equidistribution 9.9979e-01
#   75   Min/Max 8.4176e-01   Residual 7.7503e-03   Equidistribution 9.9979e-01
#   76   Min/Max 8.4463e-01   Residual 7.5204e-03   Equidistribution 9.9979e-01
#   77   Min/Max 8.4081e-01   Residual 7.3143e-03   Equidistribution 9.9979e-01
#   78   Min/Max 8.4001e-01   Residual 7.1303e-03   Equidistribution 9.9979e-01
#   79   Min/Max 8.3299e-01   Residual 6.9688e-03   Equidistribution 9.9979e-01
#   80   Min/Max 8.3045e-01   Residual 6.8293e-03   Equidistribution 9.9979e-01
#   81   Min/Max 8.3226e-01   Residual 6.7117e-03   Equidistribution 9.9979e-01
#   82   Min/Max 8.2807e-01   Residual 6.6109e-03   Equidistribution 9.9979e-01
#   83   Min/Max 8.2887e-01   Residual 6.5187e-03   Equidistribution 9.9979e-01
#   84   Min/Max 8.3525e-01   Residual 6.4242e-03   Equidistribution 9.9979e-01
#   85   Min/Max 8.3968e-01   Residual 6.3267e-03   Equidistribution 9.9979e-01
#   86   Min/Max 8.4027e-01   Residual 6.2214e-03   Equidistribution 9.9979e-01
#   87   Min/Max 8.4405e-01   Residual 6.1241e-03   Equidistribution 9.9979e-01
#   88   Min/Max 8.4435e-01   Residual 6.0382e-03   Equidistribution 9.9979e-01
#   89   Min/Max 8.5000e-01   Residual 5.9655e-03   Equidistribution 9.9979e-01
#   90   Min/Max 8.5219e-01   Residual 5.9110e-03   Equidistribution 9.9979e-01
#   91   Min/Max 8.5456e-01   Residual 5.8678e-03   Equidistribution 9.9979e-01
#   92   Min/Max 8.5530e-01   Residual 5.8362e-03   Equidistribution 9.9979e-01
#   93   Min/Max 8.5827e-01   Residual 5.8107e-03   Equidistribution 9.9979e-01
#   94   Min/Max 8.6075e-01   Residual 5.8009e-03   Equidistribution 9.9979e-01
#   95   Min/Max 8.5863e-01   Residual 5.8108e-03   Equidistribution 9.9979e-01
#   96   Min/Max 8.5837e-01   Residual 5.8368e-03   Equidistribution 9.9979e-01
#   97   Min/Max 8.6093e-01   Residual 5.8752e-03   Equidistribution 9.9979e-01
#   98   Min/Max 8.6322e-01   Residual 5.9233e-03   Equidistribution 9.9979e-01
#   99   Min/Max 8.5980e-01   Residual 5.9793e-03   Equidistribution 9.9979e-01
#  100   Min/Max 8.5520e-01   Residual 6.0423e-03   Equidistribution 9.9979e-01
#  101   Min/Max 8.5293e-01   Residual 6.1091e-03   Equidistribution 9.9979e-01
#  102   Min/Max 8.5330e-01   Residual 6.1843e-03   Equidistribution 9.9979e-01
#  103   Min/Max 8.5323e-01   Residual 6.2692e-03   Equidistribution 9.9979e-01
#  104   Min/Max 8.4953e-01   Residual 6.3594e-03   Equidistribution 9.9979e-01
#  105   Min/Max 8.4569e-01   Residual 6.4636e-03   Equidistribution 9.9979e-01
#  106   Min/Max 8.3827e-01   Residual 6.5793e-03   Equidistribution 9.9979e-01
#  107   Min/Max 8.3582e-01   Residual 6.7044e-03   Equidistribution 9.9979e-01
#  108   Min/Max 8.3662e-01   Residual 6.8387e-03   Equidistribution 9.9979e-01
#  109   Min/Max 8.3222e-01   Residual 6.9715e-03   Equidistribution 9.9979e-01
#  110   Min/Max 8.3315e-01   Residual 7.1008e-03   Equidistribution 9.9979e-01
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/firedrake/firedrake/interpolation.py:117, in Interpolator.interpolate(self, output, transpose, *function)
#     116 try:
# --> 117     assembled_interpolator = self.frozen_assembled_interpolator
#     118     copy_required = True
#
# AttributeError: 'Interpolator' object has no attribute 'frozen_assembled_interpolator'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/global_kernel.py:314, in GlobalKernel.__call__(self, comm, *args)
#     313 try:
# --> 314     func = self._func_cache[key]
#     315 except KeyError:
#
# KeyError: 140338506508560
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 46
#      44     return monitor
#      45 mover = MongeAmpereMover(mesh, pde_monitor, u, method="relaxation")
# ---> 46 mover.move()
#      47 end_time = time.time()
#      48 elapsed_time = end_time - start_time
#
# File PETSc/Log.pyx:115, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File PETSc/Log.pyx:116, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# Cell In[24], line 118, in MongeAmpereMover_Relaxation.move(self)
#     115 self.mesh.coordinates.assign(self.x)
#     117 # Update monitor function
# --> 118 self.monitor.interpolate(self.monitor_function(self.mesh,self.u))
#     119 assemble(self.L_P0, tensor=self.volume)
#     120 self.volume.interpolate(self.volume / self.original_volume)
#
# File PETSc/Log.pyx:115, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File PETSc/Log.pyx:116, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/firedrake/firedrake/function.py:376, in Function.interpolate(self, expression, subset, ad_block_tag)
#     370 r"""Interpolate an expression onto this :class:`Function`.
#     371
#     372 :param expression: a UFL expression to interpolate
#     373 :param ad_block_tag: string for tagging the resulting block on the Pyadjoint tape
#     374 :returns: this :class:`Function` object"""
#     375 from firedrake import interpolation
# --> 376 return interpolation.interpolate(expression, self, subset=subset, ad_block_tag=ad_block_tag)
#
# File PETSc/Log.pyx:115, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File PETSc/Log.pyx:116, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/firedrake/firedrake/interpolation.py:62, in interpolate(expr, V, subset, access, ad_block_tag)
#      29 @PETSc.Log.EventDecorator()
#      30 def interpolate(expr, V, subset=None, access=op2.WRITE, ad_block_tag=None):
#      31     """Interpolate an expression onto a new function in V.
#      32
#      33     :arg expr: a UFL expression.
#    (...)
#      60
#      61     """
# ---> 62     return Interpolator(expr, V, subset=subset, access=access).interpolate(ad_block_tag=ad_block_tag)
#
# File PETSc/Log.pyx:115, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File PETSc/Log.pyx:116, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/firedrake/firedrake/adjoint/interpolate.py:22, in annotate_interpolate.<locals>.wrapper(interpolator, *function, **kwargs)
#      19     tape.add_block(block)
#      21 with stop_annotating():
# ---> 22     output = interpolate(interpolator, *function, **kwargs)
#      24 if annotate:
#      25     from firedrake import Function
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/firedrake/firedrake/interpolation.py:120, in Interpolator.interpolate(self, output, transpose, *function)
#     118     copy_required = True
#     119 except AttributeError:
# --> 120     assembled_interpolator = self.callable()
#     121     copy_required = False  # Return the original
#     122     if self.freeze_expr:
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/firedrake/firedrake/interpolation.py:232, in make_interpolator.<locals>.callable(loops, f)
#     230 def callable(loops, f):
#     231     for l in loops:
# --> 232         l()
#     233     return f
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/parloop.py:206, in Parloop.compute(self)
#     203 @mpi.collective
#     204 def compute(self):
#     205     # Parloop.compute is an alias for Parloop.__call__
# --> 206     self()
#
# File PETSc/Log.pyx:115, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File PETSc/Log.pyx:116, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/parloop.py:215, in Parloop.__call__(self)
#     213 orig_lgmaps = self.replace_lgmaps()
#     214 self.global_to_local_begin()
# --> 215 self._compute(self.iterset.core_part)
#     216 self.global_to_local_end()
#     217 self._compute(self.iterset.owned_part)
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/parloop.py:197, in Parloop._compute(self, part)
#     195 with self._compute_event():
#     196     PETSc.Log.logFlops(part.size*self.num_flops)
# --> 197     self.global_kernel(self.comm, part.offset, part.offset+part.size, *self.arglist)
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/global_kernel.py:316, in GlobalKernel.__call__(self, comm, *args)
#     314     func = self._func_cache[key]
#     315 except KeyError:
# --> 316     func = self.compile(comm)
#     317     self._func_cache[key] = func
#     318 func(*args)
#
# File PETSc/Log.pyx:115, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File PETSc/Log.pyx:116, in petsc4py.PETSc.Log.EventDecorator.decorator.wrapped_func()
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/global_kernel.py:387, in GlobalKernel.compile(self, comm)
#     375 cppargs = (
#     376     tuple("-I%s/include" % d for d in get_petsc_dir())
#     377     + tuple("-I%s" % d for d in self.local_kernel.include_dirs)
#     378     + ("-I%s" % os.path.abspath(os.path.dirname(__file__)),)
#     379 )
#     380 ldargs = (
#     381     tuple("-L%s/lib" % d for d in get_petsc_dir())
#     382     + tuple("-Wl,-rpath,%s/lib" % d for d in get_petsc_dir())
#     383     + ("-lpetsc", "-lm")
#     384     + tuple(self.local_kernel.ldargs)
#     385 )
# --> 387 return compilation.load(self, extension, self.name,
#     388                         cppargs=cppargs,
#     389                         ldargs=ldargs,
#     390                         restype=ctypes.c_int,
#     391                         comm=comm)
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/compilation.py:606, in load(jitmodule, extension, fn_name, cppargs, ldargs, argtypes, restype, comm)
#     604         exe = configuration["cc"] or "mpicc"
#     605     compiler = sniff_compiler(exe)
# --> 606 dll = compiler(cppargs, ldargs, cpp=cpp, comm=comm).get_so(code, extension)
#     608 if isinstance(jitmodule, GlobalKernel):
#     609     _add_profiling_events(dll, code.local_kernel.events)
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/compilation.py:182, in Compiler.__init__(self, extra_compiler_flags, extra_linker_flags, cpp, comm)
#     180 def __init__(self, extra_compiler_flags=(), extra_linker_flags=(), cpp=False, comm=None):
#     181     # Get compiler version ASAP since it is used in __repr__
# --> 182     self.sniff_compiler_version()
#     184     self._extra_compiler_flags = tuple(extra_compiler_flags)
#     185     self._extra_linker_flags = tuple(extra_linker_flags)
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/compilation.py:458, in LinuxGnuCompiler.sniff_compiler_version(self, cpp)
#     457 def sniff_compiler_version(self, cpp=False):
# --> 458     super(LinuxGnuCompiler, self).sniff_compiler_version()
#     459     if self.version >= Version("7.0"):
#     460         try:
#     461             # gcc-7 series only spits out patch level on dumpfullversion.
#
# File ~/Desktop/install_firedrake_adapt/firedrake-adapt/src/PyOP2/pyop2/compilation.py:253, in Compiler.sniff_compiler_version(self, cpp)
#     251 for dumpstring in ["-dumpfullversion", "-dumpversion"]:
#     252     try:
# --> 253         output = subprocess.run(
#     254             [exe, dumpstring],
#     255             stdout=subprocess.PIPE,
#     256             stderr=subprocess.PIPE,
#     257             check=True,
#     258             encoding="utf-8"
#     259         ).stdout
#     260         self.version = Version(output)
#     261         break
#
# File /usr/lib/python3.8/subprocess.py:493, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     490     kwargs['stdout'] = PIPE
#     491     kwargs['stderr'] = PIPE
# --> 493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
#     495         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /usr/lib/python3.8/subprocess.py:858, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     854         if self.text_mode:
#     855             self.stderr = io.TextIOWrapper(self.stderr,
#     856                     encoding=encoding, errors=errors)
# --> 858     self._execute_child(args, executable, preexec_fn, close_fds,
#     859                         pass_fds, cwd, env,
#     860                         startupinfo, creationflags, shell,
#     861                         p2cread, p2cwrite,
#     862                         c2pread, c2pwrite,
#     863                         errread, errwrite,
#     864                         restore_signals, start_new_session)
#     865 except:
#     866     # Cleanup if the child failed starting.
#     867     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /usr/lib/python3.8/subprocess.py:1660, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1658 errpipe_data = bytearray()
#    1659 while True:
# -> 1660     part = os.read(errpipe_read, 50000)
#    1661     errpipe_data += part
#    1662     if not part or len(errpipe_data) > 50000:
#
# KeyboardInterrupt:

# %%
# Read the data
with open("relaxation_converge_smalldt.txt", "r") as f:
    lines = f.readlines()

# Extract the residuals
iterations = []
residuals = []
for line in lines:
    data = line.split()
    iterations.append(int(data[0]))
    residuals.append(float(data[4]))


fig, axes = plt.subplots(1, 2, figsize=(16, 6))
# Plot the residual convergence on the first axis
axes[0].plot(iterations, residuals, marker='o', linestyle='-')
axes[0].set_xlabel('Iterations')
axes[0].set_ylabel('Residual')
axes[0].set_title('Residual Convergence for 40x40 Mesh with dt = 0.04, time taken:51s')
axes[0].grid(True)
axes[0].set_yscale('log')

# Plot the mesh on the second axis
triplot(adapted_meshes[0], axes=axes[1])
axes[1].set_title("40*40 mesh, dt = 0.04")
plt.tight_layout()
plt.show()

# %%
# Create lists to store all iterations and residuals
all_iterations = []
all_residuals = []

# Loop through the range of file names
for i in range(1, 4):
    # Create the file name based on the current index
    filename = f"relaxation_{10*i}*{10*i}.txt"
    
    # Read the data
    with open(filename, "r") as f:
        lines = f.readlines()
    
    # Extract the residuals
    iterations = []
    residuals = []
    for line in lines:
        data = line.split()
        iterations.append(int(data[0]))
        residuals.append(float(data[4]))
    
    # Store the extracted iterations and residuals in the overall lists
    all_iterations.append(iterations)
    all_residuals.append(residuals)

# At the end of this loop:
# all_iterations[i] contains the iterations for the i-th file
# all_residuals[i] contains the residuals for the i-th file

# Create a new plot
plt.figure(figsize=(10, 6))

# Loop through the data and plot each set
for i in range(len(all_iterations)):
    label_name = f"relaxation_{10*(i+1)}*{10*(i+1)}"
    plt.plot(all_iterations[i], all_residuals[i], label=label_name, marker='o', linestyle='-')

# Add title, labels, legend, etc.
plt.title("Residuals from Different Mesh Sizes")
plt.xlabel("Iterations")
plt.ylabel("Residuals")
plt.yscale("log")  # if you want a logarithmic scale for residuals
plt.legend()
plt.grid(True, which="both", linestyle="-", linewidth=0.5)

# Show the plot
plt.tight_layout()
plt.show()
